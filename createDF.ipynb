# %% [markdown]
# - **Orginally created by: Samuel Hobbs on 12/8/2024**
# - **Last edited by: Ben Harris 1/9/2024**

# %% [markdown]
# ## The script’s primary goal is to:
#
# - Read hyperspectral .tif files from designated directories.
#
# - Check that each .tif file matches a valid resolution range (e.g., 4.0 - 7.0 currently).
#
# - Verify that each .tif file has a label in a corresponding CSV (via sample number).
#
# - Convert each .tif file into a pandas DataFrame where each row represents one pixel, and columns represent the spectral bands plus additional metadata (e.g., filename, label, resolution shape).
#
# - Concatenate all the individual DataFrames into a single large DataFrame of pixel-level data for all valid .tif files.
#
# - Save the resulting DataFrame (and an accompanying file-UID map) as a CSV file.
#
# - Once that main CSV is saved we add pixel-level coordinates within each image used for displaying results as well as post-processing morphology.

# %% [markdown]
# ## Setup

# %% [markdown]
# ### Installs

# %%
# !pip install rasterio
# Out:
# Requirement already satisfied: rasterio in /usr/local/lib/python3.10/dist-packages (1.4.3)
# Requirement already satisfied: affine in /usr/local/lib/python3.10/dist-packages (from rasterio) (2.4.0)
# Requirement already satisfied: attrs in /usr/local/lib/python3.10/dist-packages (from rasterio) (24.3.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from rasterio) (2024.12.14)
# Requirement already satisfied: click>=4.0 in /usr/local/lib/python3.10/dist-packages (from rasterio) (8.1.8)
# Requirement already satisfied: cligj>=0.5 in /usr/local/lib/python3.10/dist-packages (from rasterio) (0.7.2)
# Requirement already satisfied: numpy>=1.24 in /usr/local/lib/python3.10/dist-packages (from rasterio) (1.26.4)
# Requirement already satisfied: click-plugins in /usr/local/lib/python3.10/dist-packages (from rasterio) (1.1.1)
# Requirement already satisfied: pyparsing in /usr/local/lib/python3.10/dist-packages (from rasterio) (3.2.1)

# %% [markdown]
# ### Imports

# %%
import rasterio
from rasterio.plot import show
import pandas as pd
import numpy as np
from os import listdir
from os.path import isfile, join, basename, normpath
from google.colab import drive
from ast import literal_eval

# %% [markdown]
# ### Connect Google Drive

# %%
drive.mount('/content/drive/')
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).

# %% [markdown]
# ### File Paths
# NOTE: Please update these paths as needed!

# %%
#Directories
main_dir    = '/content/drive/Shareddrives/Land_Classification_Training_shared/Land_Classification_training_work/'
samples_dir = join(main_dir, 'Samples/')  # Directory where the .tif files & resolution CSV are

tif_dir      = join(samples_dir, 'ANG_L2A_v2_sample_subset')     # Directory containing all .tif files
res_csv_path = join(samples_dir, 'ANG_L2A_v2_sample_subset_resolutions.csv')  # CSV with columns: file_name, x_res, y_res
labels_csv   = join(main_dir, 'labels.csv')  # CSV containing labels for each sample_num

# Output CSV file names and paths
csv_dir                 = join(main_dir, 'Updated/')
csv_file_name_samples   = 'samples.csv'
csv_file_name_uid       = 'files.csv'
path_to_save_sample_csv = join(csv_dir, csv_file_name_samples)
path_to_save_uid_csv    = join(csv_dir, csv_file_name_uid)

# Label columns in labels.csv
label_col_sample_num = 'Sample_num'
label_col_label      = 'Class'

# %% [markdown]
# ## Functions

# %% [markdown]
# ### General Functions

# %%
def get_labels(
  file_path,
  col1='Sample_num',
  col2='Class',
  name_col_id='Sample_num',
  name_col_label='Label'
):
  """
  Reads a CSV of labels from `file_path`. Subsets two columns (col1, col2),
  renames them, and sorts by col1 ascending. Returns the resulting DataFrame.

  Paramaters:
    file_path: Path to the labels CSV.
    col1: Name of the column in the CSV that holds the sample number.
    col2: Name of the column in the CSV that holds the label/class.
    name_col_id: Desired name for the ID column in the returned DataFrame.
    name_col_label: Desired name for the label column in the returned DataFrame.

  Returns:
    A sorted Pandas DataFrame with columns [name_col_id, name_col_label].
  """
  df_labels = (
    pd.read_csv(file_path)[[col1, col2]]
    .rename(columns={col1: name_col_id, col2: name_col_label})
    .sort_values(by=name_col_id, ascending=True)
  )
  return df_labels

# %%
def trim_data_files(
  filenames,
  labels,
  sample_num_col_name='Sample_num'
):
  """
  Trims a list of filenames by matching them to provided labels (by sample_num).
  Allows for multiple filenames per sample number. Only retains filenames whose
  leading integer matches a label's sample number.

  Debug prints are included to help diagnose matching issues:
    - filename_num: the leading integer from the filename
    - label_num   : the label number from the labels DataFrame
    - count_label : index tracking which label we're on
    - count_files : index tracking which file we're on

  Parameters:
    filenames: Sorted list or array of filename strings (ex: '2_ang20231028t095542_004.tif').
    labels: Pandas DataFrame of labels, sorted by sample_num_col_name.
    sample_num_col_name: Column in `labels` that matches the file's leading integer.

  Returns:
  A numpy array of matching filenames.
  """
  trimmed_filenames = []

  size_label      = labels.shape[0]
  size_filenames  = len(filenames)

  count_label     = 0
  count_filenames = 0

  # Debug: print to see how many total files and labels we have
  print(f"[DEBUG] Starting trim_data_files:")
  print(f"        Total Filenames: {size_filenames}")
  print(f"        Total Labels   : {size_label}")

  while (count_label < size_label and count_filenames < size_filenames):
    # Extract the sample number from the filename
    filename_num_str = filenames[count_filenames].split('_')[0]
    filename_num     = int(filename_num_str)  # int('2') -> 2, for example

    # Current label number
    label_num = int(labels[sample_num_col_name].iloc[count_label])

    # Debug print to see each comparison
    print(f"[DEBUG] Comparing filename: '{filenames[count_filenames]}' "
          f"(filename_num={filename_num}) with label_num={label_num} "
          f"[count_label={count_label}, count_filenames={count_filenames}]")

    if filename_num == label_num:
      # We have a match; append the filename to our valid list
      trimmed_filenames.append(filenames[count_filenames])

      # Move to the next filename (but keep the same label index
      # in case there are more files with the same sample number)
      count_filenames += 1

    elif filename_num < label_num:
      # This filename's sample number is behind the current label's sample number.
      # So, there's no label for it. We discard this filename and move on.
      count_filenames += 1

    else:  # filename_num > label_num
      # This file's sample number has overshot the label number.
      # That means we're done with this label_num; move to the next label.
      count_label += 1

  # Double-check we matched something
  assert len(trimmed_filenames) > 0, (
    "No filenames match the given labels. Debug Info:\n"
    f"  # Filenames: {size_filenames}\n"
    f"  # Labels: {size_label}\n"
    f"  Possibly the file naming convention or sample_num in CSV do not align."
  )

  return np.array(trimmed_filenames)

# %%
def check_res(
  filename,
  res_dict,
  min_res_bound=4.0,
  max_res_bound=7.0
):
  """
  Checks if the x/y resolution of a given filename is within the min/max bound.
  Instead of reading resolution from Rasterio, we read from a dictionary
  (filename -> (xres, yres)) that was loaded from a CSV file.

  Parameters:
    filename: The .tif filename (string).
    res_dict: Dictionary with structure {filename: (xres, yres)}.
    min_res_bound: Minimum allowed resolution (inclusive).
    max_res_bound: Maximum allowed resolution (inclusive).

  Returns:
    True if within bounds; otherwise False.
  """
  if filename not in res_dict:
    return False

  xres, yres = res_dict[filename]

  if (
    xres < min_res_bound or xres > max_res_bound
    or yres < min_res_bound or yres > max_res_bound
  ):
    return False

  return True

# %%
def tif_to_arr(filepath):
  """
  Opens a .tif file with Rasterio and returns its raw data as a numpy array,
  plus the shape as a string.

  Parameters:
    filepath: Full path to the .tif file.

  Returns:
    data_3D -> numpy array of shape (bands, rows, cols)
    shape_str -> string representation of (rows, cols)
  """
  with rasterio.open(filepath) as dataset:
      data_array  = dataset.read()      # shape (bands, rows, cols)
      shape_str   = str(dataset.shape)  # e.g. '(10, 10)'
  return data_array, shape_str

# %%
def convert_3D_to_1D(data_3D):
  """
  Reshapes a 3D array (bands, rows, cols) into (rows*cols, bands).

  Parameters:
    data_3D: NumPy array of shape (num_bands, num_rows, num_cols).

  Returns:
    NumPy array of shape (num_pixels, num_bands).
  """
  # Flatten rows*cols, then transpose:
  return data_3D.reshape(data_3D.shape[0], -1).T

# %%
def get_filenames(directory_path):
  """
  Retrieves all files in a directory (no subfolders),
  then sorts them by the integer prefix before '_' in the filename.

  Parameters:
    directory_path: Path to the directory containing .tif files.

  Returns:
    A sorted np.array of filenames.
  """
  files_in_dir = [
    f for f in listdir(directory_path)
    if isfile(join(directory_path, f)) and f.lower().endswith('.tif')
  ]
  # Sort by integer portion (split on '_')
  files_in_dir_sorted = sorted(files_in_dir, key=lambda x: int(x.split('_')[0]))
  return np.array(files_in_dir_sorted)

# %%
def make_pandas_dataframe(
  dir_path,
  filename,
  sample_num,
  label=pd.NA,
  uid=0
):
  """
  Converts one .tif file (with known valid resolution) to a pandas DataFrame.
  Automatically determines how many spectral bands are available and includes:
    - All frequency columns [frq0, frq1, ...],
    - Sample_num (parsed from the filename or passed in),
    - Per-pixel row, col coordinates,
    - Label,
    - Shape of the overall image,
    - Unique file ID (uid),
    - The filename itself.

  Parameters:
    dir_path: Directory where the .tif file resides.
    filename: The .tif file name.
    sample_num: The integer sample number extracted from the filename (leading prefix).
    label: The label/class for all pixels in this image (default: NaN).
    uid: A unique integer ID for the file (default: 0).

  Returns:
    A pandas DataFrame of shape (num_pixels, num_bands + 6) with columns:
      [frq0, frq1, ..., 'Sample_num', 'img_pxl_index', 'img_pos', 'Label',
      'Shape', 'File_UID_Num', 'File'].
  """
  filepath_full = join(dir_path, filename)

  # Read the 3D data and shape string from the .tif
  data_3D, shape_str = tif_to_arr(filepath_full)
  # data_3D shape -> (bands, rows, cols)

  # Flatten to (rows*cols, bands)
  data_2D = convert_3D_to_1D(data_3D)

  # Dynamically name frequency columns
  num_bands = data_3D.shape[0]
  freq_columns = [f"frq{i}" for i in range(num_bands)]

  # Create DataFrame with band columns
  df = pd.DataFrame(data_2D, columns=freq_columns)

  # Basic metadata
  df['Sample_num']   = sample_num
  df['Label']        = label
  df['Shape']        = shape_str
  df['File_UID_Num'] = uid
  df['File']         = filename

  # Add per-pixel index & (row, col)
  #    - The index of the row in df matches the flattened pixel index
  df['img_pxl_index'] = df.index

  # Parse shape_str -> (rows, cols) as integers
  # shape_str is something like '(100, 100)'
  shape_tuple = literal_eval(shape_str)   # e.g., shape_tuple = (100, 100)
  rows, cols  = shape_tuple

  # Compute row, col for each pixel index
  df['row_coord'] = df['img_pxl_index'] // cols
  df['col_coord'] = df['img_pxl_index'] %  cols

  # Optional: store a combined tuple
  df['img_pos']   = list(zip(df['row_coord'], df['col_coord']))

  # Return final DataFrame
  return df

# %% [markdown]
# ### Main Function Call

# %%
def get_all_data_single_dir(
  tif_directory,
  label_csv_path,
  res_dict,
  min_res=4.0,
  max_res=7.0,
  label_col_1='Sample_num',
  label_col_2='Class'
):
  """
  Reads all .tif files in `tif_directory` and their corresponding labels from `label_csv_path`.
  Checks resolution using `res_dict`. Creates a DataFrame of all valid .tif files,
  automatically extracting the number of spectral bands and computing pixel coordinates.
  """
  print("=== Starting Data Aggregation ===")

  # Load label CSV
  labels = get_labels(
    file_path=label_csv_path,
    col1=label_col_1,
    col2=label_col_2,
    name_col_id='Sample_num',
    name_col_label='Label'
  )

  # Gather and sort filenames in directory
  filenames = get_filenames(tif_directory)

  # Trim filenames to only those that have a matching label
  print("Trimming filenames to match labels...")
  trimmed_filenames = trim_data_files(filenames, labels, 'Sample_num')
  print(f"Number of files with matching labels: {len(trimmed_filenames)} / {len(filenames)}")

  df_list     = []
  included    = []
  uid_counter = 1

  # Iterate over each trimmed filename
  for fname in trimmed_filenames:
    # Extract sample_num from the filename prefix
    sample_num  = int(fname.split('_')[0])

    # Retrieve corresponding label from the labels DataFrame
    label_value = labels.loc[labels['Sample_num'] == sample_num, 'Label'].values[0]

    # Check resolution using CSV-based res_dict
    if check_res(fname, res_dict, min_res_bound=min_res, max_res_bound=max_res):
      # Convert this .tif to a DataFrame (including pixel coords, sample_num, etc.)
      df_temp = make_pandas_dataframe(
          dir_path   = tif_directory,
          filename   = fname,
          sample_num = sample_num,
          label      = label_value,
          uid        = uid_counter
      )

      df_list.append(df_temp)
      included.append((label_value, uid_counter, fname))
      uid_counter += 1

  # Concatenate all valid DataFrames
  if not df_list:
    raise ValueError("No valid .tif files passed the resolution check.")

  df_all = pd.concat(df_list, ignore_index=True)

  # Create a file-level DataFrame
  df_files = pd.DataFrame(included, columns=['Label','UID','Filename'])

  print("=== Data Aggregation Complete ===")
  return df_all, df_files

# %% [markdown]
# ## Main Run

# %%
#############################################
#               LOAD RESOLUTIONS
#############################################
# Loading the CSV of x_res and y_res so that we can check
# resolutions without relying on Rasterio for this information. (bit quicker given we have the metadata)

# The CSV (res_csv_path) must have these columns: file_name, x_res, y_res

# Load the CSV of x_res,y_res -> res_dict
df_resolutions = pd.read_csv(res_csv_path)

res_dict = {}
for idx, row in df_resolutions.iterrows():
  filename = row['file_name']   # must match exactly the .tif filename
  xres     = float(row['x_res'])
  yres     = float(row['y_res'])
  res_dict[filename] = (xres, yres)

# %%
# Run the main data retrieval using our single directory approach
# CAUTION: So Slow... this took 22 to 41 minutes to run. Depends on Google, idk?
# Get all data from the single directory
df, valid_files = get_all_data_single_dir(
    tif_directory   = tif_dir,
    label_csv_path  = labels_csv,
    res_dict        = res_dict,
    min_res         = 4.0,
    max_res         = 7.0,
    label_col_1     = label_col_sample_num,
    label_col_2     = label_col_label
)
# Out:
# Streaming output truncated to the last 5000 lines.
# [DEBUG] Comparing filename: '5579_ang20231110t081307_010.tif' (filename_num=5579) with label_num=5577 [count_label=844, count_filenames=1607]
# [DEBUG] Comparing filename: '5579_ang20231110t081307_010.tif' (filename_num=5579) with label_num=5579 [count_label=845, count_filenames=1607]
# [DEBUG] Comparing filename: '5579_ang20231110t082850_005.tif' (filename_num=5579) with label_num=5579 [count_label=845, count_filenames=1608]
# [DEBUG] Comparing filename: '5579_ang20231122t080745_003.tif' (filename_num=5579) with label_num=5579 [count_label=845, count_filenames=1609]
# [DEBUG] Comparing filename: '5580_ang20231110t081307_010.tif' (filename_num=5580) with label_num=5579 [count_label=845, count_filenames=1610]
# [DEBUG] Comparing filename: '5580_ang20231110t081307_010.tif' (filename_num=5580) with label_num=5580 [count_label=846, count_filenames=1610]
# [DEBUG] Comparing filename: '5580_ang20231122t080745_003.tif' (filename_num=5580) with label_num=5580 [count_label=846, count_filenames=1611]
# [DEBUG] Comparing filename: '5583_ang20231122t080745_003.tif' (filename_num=5583) with label_num=5580 [count_label=846, count_filenames=1612]
# [DEBUG] Comparing filename: '5583_ang20231122t080745_003.tif' (filename_num=5583) with label_num=5583 [count_label=847, count_filenames=1612]
# [DEBUG] Comparing filename: '5583_ang20231110t081307_010.tif' (filename_num=5583) with label_num=5583 [count_label=847, count_filenames=1613]
# [DEBUG] Comparing filename: '5585_ang20231110t084202_009.tif' (filename_num=5585) with label_num=5583 [count_label=847, count_filenames=1614]
# [DEBUG] Comparing filename: '5585_ang20231110t084202_009.tif' (filename_num=5585) with label_num=5585 [count_label=848, count_filenames=1614]
# [DEBUG] Comparing filename: '5585_ang20231110t082850_005.tif' (filename_num=5585) with label_num=5585 [count_label=848, count_filenames=1615]
# [DEBUG] Comparing filename: '5586_ang20231110t084202_010.tif' (filename_num=5586) with label_num=5585 [count_label=848, count_filenames=1616]
# [DEBUG] Comparing filename: '5586_ang20231110t084202_010.tif' (filename_num=5586) with label_num=5586 [count_label=849, count_filenames=1616]
# [DEBUG] Comparing filename: '5586_ang20231110t085753_004.tif' (filename_num=5586) with label_num=5586 [count_label=849, count_filenames=1617]
# [DEBUG] Comparing filename: '5587_ang20231110t082850_005.tif' (filename_num=5587) with label_num=5586 [count_label=849, count_filenames=1618]
# [DEBUG] Comparing filename: '5587_ang20231110t082850_005.tif' (filename_num=5587) with label_num=5587 [count_label=850, count_filenames=1618]
# [DEBUG] Comparing filename: '5587_ang20231110t081307_010.tif' (filename_num=5587) with label_num=5587 [count_label=850, count_filenames=1619]
# [DEBUG] Comparing filename: '5587_ang20231122t080745_003.tif' (filename_num=5587) with label_num=5587 [count_label=850, count_filenames=1620]
# [DEBUG] Comparing filename: '5588_ang20231110t080035_004.tif' (filename_num=5588) with label_num=5587 [count_label=850, count_filenames=1621]
# [DEBUG] Comparing filename: '5588_ang20231110t080035_004.tif' (filename_num=5588) with label_num=5588 [count_label=851, count_filenames=1621]
# [DEBUG] Comparing filename: '5588_ang20231110t081307_010.tif' (filename_num=5588) with label_num=5588 [count_label=851, count_filenames=1622]
# [DEBUG] Comparing filename: '5589_ang20231022t124546_006.tif' (filename_num=5589) with label_num=5588 [count_label=851, count_filenames=1623]
# [DEBUG] Comparing filename: '5589_ang20231022t124546_006.tif' (filename_num=5589) with label_num=5589 [count_label=852, count_filenames=1623]
# [DEBUG] Comparing filename: '5590_ang20231022t124546_006.tif' (filename_num=5590) with label_num=5589 [count_label=852, count_filenames=1624]
# [DEBUG] Comparing filename: '5590_ang20231022t124546_006.tif' (filename_num=5590) with label_num=5590 [count_label=853, count_filenames=1624]
# [DEBUG] Comparing filename: '5590_ang20231022t122317_009.tif' (filename_num=5590) with label_num=5590 [count_label=853, count_filenames=1625]
# [DEBUG] Comparing filename: '5594_ang20231110t082850_009.tif' (filename_num=5594) with label_num=5590 [count_label=853, count_filenames=1626]
# [DEBUG] Comparing filename: '5594_ang20231110t082850_009.tif' (filename_num=5594) with label_num=5594 [count_label=854, count_filenames=1626]
# [DEBUG] Comparing filename: '5594_ang20231110t084202_004.tif' (filename_num=5594) with label_num=5594 [count_label=854, count_filenames=1627]
# [DEBUG] Comparing filename: '5596_ang20231110t082850_003.tif' (filename_num=5596) with label_num=5594 [count_label=854, count_filenames=1628]
# [DEBUG] Comparing filename: '5596_ang20231110t082850_003.tif' (filename_num=5596) with label_num=5596 [count_label=855, count_filenames=1628]
# [DEBUG] Comparing filename: '5596_ang20231116t070314_000.tif' (filename_num=5596) with label_num=5596 [count_label=855, count_filenames=1629]
# [DEBUG] Comparing filename: '5596_ang20231110t081307_012.tif' (filename_num=5596) with label_num=5596 [count_label=855, count_filenames=1630]
# [DEBUG] Comparing filename: '5596_ang20231122t080745_005.tif' (filename_num=5596) with label_num=5596 [count_label=855, count_filenames=1631]
# [DEBUG] Comparing filename: '5597_ang20231110t082850_003.tif' (filename_num=5597) with label_num=5596 [count_label=855, count_filenames=1632]
# [DEBUG] Comparing filename: '5597_ang20231110t082850_003.tif' (filename_num=5597) with label_num=5597 [count_label=856, count_filenames=1632]
# [DEBUG] Comparing filename: '5597_ang20231110t084202_012.tif' (filename_num=5597) with label_num=5597 [count_label=856, count_filenames=1633]
# [DEBUG] Comparing filename: '5597_ang20231122t080745_005.tif' (filename_num=5597) with label_num=5597 [count_label=856, count_filenames=1634]
# [DEBUG] Comparing filename: '5599_ang20231110t081307_012.tif' (filename_num=5599) with label_num=5597 [count_label=856, count_filenames=1635]
# [DEBUG] Comparing filename: '5599_ang20231110t081307_012.tif' (filename_num=5599) with label_num=5599 [count_label=857, count_filenames=1635]
# [DEBUG] Comparing filename: '5599_ang20231122t080745_005.tif' (filename_num=5599) with label_num=5599 [count_label=857, count_filenames=1636]
# [DEBUG] Comparing filename: '5599_ang20231116t070314_000.tif' (filename_num=5599) with label_num=5599 [count_label=857, count_filenames=1637]
# [DEBUG] Comparing filename: '5599_ang20231110t082850_003.tif' (filename_num=5599) with label_num=5599 [count_label=857, count_filenames=1638]
# [DEBUG] Comparing filename: '5600_ang20231110t080035_003.tif' (filename_num=5600) with label_num=5599 [count_label=857, count_filenames=1639]
# [DEBUG] Comparing filename: '5600_ang20231110t080035_003.tif' (filename_num=5600) with label_num=5600 [count_label=858, count_filenames=1639]
# [DEBUG] Comparing filename: '5603_ang20231110t080035_001.tif' (filename_num=5603) with label_num=5600 [count_label=858, count_filenames=1640]
# [DEBUG] Comparing filename: '5603_ang20231110t080035_001.tif' (filename_num=5603) with label_num=5603 [count_label=859, count_filenames=1640]
# [DEBUG] Comparing filename: '5603_ang20231122t084424_001.tif' (filename_num=5603) with label_num=5603 [count_label=859, count_filenames=1641]
# [DEBUG] Comparing filename: '5611_ang20231110t081307_001.tif' (filename_num=5611) with label_num=5603 [count_label=859, count_filenames=1642]
# [DEBUG] Comparing filename: '5611_ang20231110t081307_001.tif' (filename_num=5611) with label_num=5611 [count_label=860, count_filenames=1642]
# [DEBUG] Comparing filename: '5611_ang20231110t082850_011.tif' (filename_num=5611) with label_num=5611 [count_label=860, count_filenames=1643]
# [DEBUG] Comparing filename: '5613_ang20231110t081307_001.tif' (filename_num=5613) with label_num=5611 [count_label=860, count_filenames=1644]
# [DEBUG] Comparing filename: '5613_ang20231110t081307_001.tif' (filename_num=5613) with label_num=5613 [count_label=861, count_filenames=1644]
# [DEBUG] Comparing filename: '5623_ang20231109t124405_006.tif' (filename_num=5623) with label_num=5613 [count_label=861, count_filenames=1645]
# [DEBUG] Comparing filename: '5623_ang20231109t124405_006.tif' (filename_num=5623) with label_num=5623 [count_label=862, count_filenames=1645]
# [DEBUG] Comparing filename: '5624_ang20231109t124405_006.tif' (filename_num=5624) with label_num=5623 [count_label=862, count_filenames=1646]
# [DEBUG] Comparing filename: '5624_ang20231109t124405_006.tif' (filename_num=5624) with label_num=5624 [count_label=863, count_filenames=1646]
# [DEBUG] Comparing filename: '5624_ang20231109t123229_001.tif' (filename_num=5624) with label_num=5624 [count_label=863, count_filenames=1647]
# [DEBUG] Comparing filename: '5627_ang20231110t082850_009.tif' (filename_num=5627) with label_num=5624 [count_label=863, count_filenames=1648]
# [DEBUG] Comparing filename: '5627_ang20231110t082850_009.tif' (filename_num=5627) with label_num=5627 [count_label=864, count_filenames=1648]
# [DEBUG] Comparing filename: '5627_ang20231110t081307_004.tif' (filename_num=5627) with label_num=5627 [count_label=864, count_filenames=1649]
# [DEBUG] Comparing filename: '5629_ang20231110t081307_004.tif' (filename_num=5629) with label_num=5627 [count_label=864, count_filenames=1650]
# [DEBUG] Comparing filename: '5629_ang20231110t081307_004.tif' (filename_num=5629) with label_num=5629 [count_label=865, count_filenames=1650]
# [DEBUG] Comparing filename: '5629_ang20231110t082850_009.tif' (filename_num=5629) with label_num=5629 [count_label=865, count_filenames=1651]
# [DEBUG] Comparing filename: '5632_ang20231110t080035_008.tif' (filename_num=5632) with label_num=5629 [count_label=865, count_filenames=1652]
# [DEBUG] Comparing filename: '5632_ang20231110t080035_008.tif' (filename_num=5632) with label_num=5632 [count_label=866, count_filenames=1652]
# [DEBUG] Comparing filename: '5632_ang20231110t081307_005.tif' (filename_num=5632) with label_num=5632 [count_label=866, count_filenames=1653]
# [DEBUG] Comparing filename: '5633_ang20231110t081307_005.tif' (filename_num=5633) with label_num=5632 [count_label=866, count_filenames=1654]
# [DEBUG] Comparing filename: '5633_ang20231110t081307_005.tif' (filename_num=5633) with label_num=5633 [count_label=867, count_filenames=1654]
# [DEBUG] Comparing filename: '5634_ang20231110t081307_005.tif' (filename_num=5634) with label_num=5633 [count_label=867, count_filenames=1655]
# [DEBUG] Comparing filename: '5634_ang20231110t081307_005.tif' (filename_num=5634) with label_num=5634 [count_label=868, count_filenames=1655]
# [DEBUG] Comparing filename: '5634_ang20231110t080035_008.tif' (filename_num=5634) with label_num=5634 [count_label=868, count_filenames=1656]
# [DEBUG] Comparing filename: '5634_ang20231110t080035_009.tif' (filename_num=5634) with label_num=5634 [count_label=868, count_filenames=1657]
# [DEBUG] Comparing filename: '5635_ang20231110t080035_005.tif' (filename_num=5635) with label_num=5634 [count_label=868, count_filenames=1658]
# [DEBUG] Comparing filename: '5635_ang20231110t080035_005.tif' (filename_num=5635) with label_num=5635 [count_label=869, count_filenames=1658]
# [DEBUG] Comparing filename: '5638_ang20231022t103357_005.tif' (filename_num=5638) with label_num=5635 [count_label=869, count_filenames=1659]
# [DEBUG] Comparing filename: '5638_ang20231022t103357_005.tif' (filename_num=5638) with label_num=5638 [count_label=870, count_filenames=1659]
# [DEBUG] Comparing filename: '5638_ang20231022t105533_010.tif' (filename_num=5638) with label_num=5638 [count_label=870, count_filenames=1660]
# [DEBUG] Comparing filename: '5639_ang20231022t103357_005.tif' (filename_num=5639) with label_num=5638 [count_label=870, count_filenames=1661]
# [DEBUG] Comparing filename: '5639_ang20231022t103357_005.tif' (filename_num=5639) with label_num=5639 [count_label=871, count_filenames=1661]
# [DEBUG] Comparing filename: '5639_ang20231022t105533_010.tif' (filename_num=5639) with label_num=5639 [count_label=871, count_filenames=1662]
# [DEBUG] Comparing filename: '5640_ang20231022t103357_005.tif' (filename_num=5640) with label_num=5639 [count_label=871, count_filenames=1663]
# [DEBUG] Comparing filename: '5640_ang20231022t103357_005.tif' (filename_num=5640) with label_num=5640 [count_label=872, count_filenames=1663]
# [DEBUG] Comparing filename: '5642_ang20231110t101341_010.tif' (filename_num=5642) with label_num=5640 [count_label=872, count_filenames=1664]
# [DEBUG] Comparing filename: '5642_ang20231110t101341_010.tif' (filename_num=5642) with label_num=5641 [count_label=873, count_filenames=1664]
# [DEBUG] Comparing filename: '5642_ang20231110t101341_010.tif' (filename_num=5642) with label_num=5642 [count_label=874, count_filenames=1664]
# [DEBUG] Comparing filename: '5643_ang20231110t080035_002.tif' (filename_num=5643) with label_num=5642 [count_label=874, count_filenames=1665]
# [DEBUG] Comparing filename: '5643_ang20231110t080035_002.tif' (filename_num=5643) with label_num=5643 [count_label=875, count_filenames=1665]
# [DEBUG] Comparing filename: '5643_ang20231110t074442_013.tif' (filename_num=5643) with label_num=5643 [count_label=875, count_filenames=1666]
# [DEBUG] Comparing filename: '5643_ang20231116t070033_003.tif' (filename_num=5643) with label_num=5643 [count_label=875, count_filenames=1667]
# [DEBUG] Comparing filename: '5645_ang20231110t080035_002.tif' (filename_num=5645) with label_num=5643 [count_label=875, count_filenames=1668]
# [DEBUG] Comparing filename: '5645_ang20231110t080035_002.tif' (filename_num=5645) with label_num=5645 [count_label=876, count_filenames=1668]
# [DEBUG] Comparing filename: '5647_ang20231122t080745_006.tif' (filename_num=5647) with label_num=5645 [count_label=876, count_filenames=1669]
# [DEBUG] Comparing filename: '5647_ang20231122t080745_006.tif' (filename_num=5647) with label_num=5647 [count_label=877, count_filenames=1669]
# [DEBUG] Comparing filename: '5647_ang20231110t081307_013.tif' (filename_num=5647) with label_num=5647 [count_label=877, count_filenames=1670]
# [DEBUG] Comparing filename: '5647_ang20231110t080035_002.tif' (filename_num=5647) with label_num=5647 [count_label=877, count_filenames=1671]
# [DEBUG] Comparing filename: '5653_ang20231110t080035_002.tif' (filename_num=5653) with label_num=5647 [count_label=877, count_filenames=1672]
# [DEBUG] Comparing filename: '5653_ang20231110t080035_002.tif' (filename_num=5653) with label_num=5653 [count_label=878, count_filenames=1672]
# [DEBUG] Comparing filename: '5655_ang20231110t080035_002.tif' (filename_num=5655) with label_num=5653 [count_label=878, count_filenames=1673]
# [DEBUG] Comparing filename: '5655_ang20231110t080035_002.tif' (filename_num=5655) with label_num=5655 [count_label=879, count_filenames=1673]
# [DEBUG] Comparing filename: '5655_ang20231110t081307_012.tif' (filename_num=5655) with label_num=5655 [count_label=879, count_filenames=1674]
# [DEBUG] Comparing filename: '5657_ang20231122t080745_005.tif' (filename_num=5657) with label_num=5655 [count_label=879, count_filenames=1675]
# [DEBUG] Comparing filename: '5657_ang20231122t080745_005.tif' (filename_num=5657) with label_num=5657 [count_label=880, count_filenames=1675]
# [DEBUG] Comparing filename: '5657_ang20231110t081307_012.tif' (filename_num=5657) with label_num=5657 [count_label=880, count_filenames=1676]
# [DEBUG] Comparing filename: '5657_ang20231110t080035_002.tif' (filename_num=5657) with label_num=5657 [count_label=880, count_filenames=1677]
# [DEBUG] Comparing filename: '5658_ang20231110t081307_012.tif' (filename_num=5658) with label_num=5657 [count_label=880, count_filenames=1678]
# [DEBUG] Comparing filename: '5658_ang20231110t081307_012.tif' (filename_num=5658) with label_num=5658 [count_label=881, count_filenames=1678]
# [DEBUG] Comparing filename: '5658_ang20231122t080745_005.tif' (filename_num=5658) with label_num=5658 [count_label=881, count_filenames=1679]
# [DEBUG] Comparing filename: '5660_ang20231110t074442_012.tif' (filename_num=5660) with label_num=5658 [count_label=881, count_filenames=1680]
# [DEBUG] Comparing filename: '5660_ang20231110t074442_012.tif' (filename_num=5660) with label_num=5660 [count_label=882, count_filenames=1680]
# [DEBUG] Comparing filename: '5664_ang20231110t074442_014.tif' (filename_num=5664) with label_num=5660 [count_label=882, count_filenames=1681]
# [DEBUG] Comparing filename: '5664_ang20231110t074442_014.tif' (filename_num=5664) with label_num=5664 [count_label=883, count_filenames=1681]
# [DEBUG] Comparing filename: '5664_ang20231122t084424_001.tif' (filename_num=5664) with label_num=5664 [count_label=883, count_filenames=1682]
# [DEBUG] Comparing filename: '5665_ang20231122t084424_001.tif' (filename_num=5665) with label_num=5664 [count_label=883, count_filenames=1683]
# [DEBUG] Comparing filename: '5665_ang20231122t084424_001.tif' (filename_num=5665) with label_num=5665 [count_label=884, count_filenames=1683]
# [DEBUG] Comparing filename: '5665_ang20231110t080035_001.tif' (filename_num=5665) with label_num=5665 [count_label=884, count_filenames=1684]
# [DEBUG] Comparing filename: '5669_ang20231109t110028_000.tif' (filename_num=5669) with label_num=5665 [count_label=884, count_filenames=1685]
# [DEBUG] Comparing filename: '5669_ang20231109t110028_000.tif' (filename_num=5669) with label_num=5669 [count_label=885, count_filenames=1685]
# [DEBUG] Comparing filename: '5671_ang20231109t105153_006.tif' (filename_num=5671) with label_num=5669 [count_label=885, count_filenames=1686]
# [DEBUG] Comparing filename: '5671_ang20231109t105153_006.tif' (filename_num=5671) with label_num=5670 [count_label=886, count_filenames=1686]
# [DEBUG] Comparing filename: '5671_ang20231109t105153_006.tif' (filename_num=5671) with label_num=5671 [count_label=887, count_filenames=1686]
# [DEBUG] Comparing filename: '5671_ang20231110t101341_011.tif' (filename_num=5671) with label_num=5671 [count_label=887, count_filenames=1687]
# [DEBUG] Comparing filename: '5678_ang20231029t102726_008.tif' (filename_num=5678) with label_num=5671 [count_label=887, count_filenames=1688]
# [DEBUG] Comparing filename: '5678_ang20231029t102726_008.tif' (filename_num=5678) with label_num=5678 [count_label=888, count_filenames=1688]
# [DEBUG] Comparing filename: '5679_ang20231029t102726_008.tif' (filename_num=5679) with label_num=5678 [count_label=888, count_filenames=1689]
# [DEBUG] Comparing filename: '5679_ang20231029t102726_008.tif' (filename_num=5679) with label_num=5679 [count_label=889, count_filenames=1689]
# [DEBUG] Comparing filename: '5680_ang20231110t101341_012.tif' (filename_num=5680) with label_num=5679 [count_label=889, count_filenames=1690]
# [DEBUG] Comparing filename: '5680_ang20231110t101341_012.tif' (filename_num=5680) with label_num=5680 [count_label=890, count_filenames=1690]
# [DEBUG] Comparing filename: '5680_ang20231109t105153_005.tif' (filename_num=5680) with label_num=5680 [count_label=890, count_filenames=1691]
# [DEBUG] Comparing filename: '5681_ang20231110t101341_012.tif' (filename_num=5681) with label_num=5680 [count_label=890, count_filenames=1692]
# [DEBUG] Comparing filename: '5681_ang20231110t101341_012.tif' (filename_num=5681) with label_num=5681 [count_label=891, count_filenames=1692]
# [DEBUG] Comparing filename: '5681_ang20231109t110028_000.tif' (filename_num=5681) with label_num=5681 [count_label=891, count_filenames=1693]
# [DEBUG] Comparing filename: '5682_ang20231025t092131_007.tif' (filename_num=5682) with label_num=5681 [count_label=891, count_filenames=1694]
# [DEBUG] Comparing filename: '5682_ang20231025t092131_007.tif' (filename_num=5682) with label_num=5682 [count_label=892, count_filenames=1694]
# [DEBUG] Comparing filename: '5682_ang20231025t094130_012.tif' (filename_num=5682) with label_num=5682 [count_label=892, count_filenames=1695]
# [DEBUG] Comparing filename: '5683_ang20231025t092131_006.tif' (filename_num=5683) with label_num=5682 [count_label=892, count_filenames=1696]
# [DEBUG] Comparing filename: '5683_ang20231025t092131_006.tif' (filename_num=5683) with label_num=5683 [count_label=893, count_filenames=1696]
# [DEBUG] Comparing filename: '5683_ang20231025t094130_013.tif' (filename_num=5683) with label_num=5683 [count_label=893, count_filenames=1697]
# [DEBUG] Comparing filename: '5684_ang20231110t074442_007.tif' (filename_num=5684) with label_num=5683 [count_label=893, count_filenames=1698]
# [DEBUG] Comparing filename: '5684_ang20231110t074442_007.tif' (filename_num=5684) with label_num=5684 [count_label=894, count_filenames=1698]
# [DEBUG] Comparing filename: '5686_ang20231110t074442_008.tif' (filename_num=5686) with label_num=5684 [count_label=894, count_filenames=1699]
# [DEBUG] Comparing filename: '5686_ang20231110t074442_008.tif' (filename_num=5686) with label_num=5686 [count_label=895, count_filenames=1699]
# [DEBUG] Comparing filename: '5687_ang20231110t074442_008.tif' (filename_num=5687) with label_num=5686 [count_label=895, count_filenames=1700]
# [DEBUG] Comparing filename: '5687_ang20231110t074442_008.tif' (filename_num=5687) with label_num=5687 [count_label=896, count_filenames=1700]
# [DEBUG] Comparing filename: '5689_ang20231110t081307_009.tif' (filename_num=5689) with label_num=5687 [count_label=896, count_filenames=1701]
# [DEBUG] Comparing filename: '5689_ang20231110t081307_009.tif' (filename_num=5689) with label_num=5689 [count_label=897, count_filenames=1701]
# [DEBUG] Comparing filename: '5689_ang20231122t080745_002.tif' (filename_num=5689) with label_num=5689 [count_label=897, count_filenames=1702]
# [DEBUG] Comparing filename: '5691_ang20231110t074442_009.tif' (filename_num=5691) with label_num=5689 [count_label=897, count_filenames=1703]
# [DEBUG] Comparing filename: '5691_ang20231110t074442_009.tif' (filename_num=5691) with label_num=5691 [count_label=898, count_filenames=1703]
# [DEBUG] Comparing filename: '5693_ang20231110t081307_009.tif' (filename_num=5693) with label_num=5691 [count_label=898, count_filenames=1704]
# [DEBUG] Comparing filename: '5693_ang20231110t081307_009.tif' (filename_num=5693) with label_num=5693 [count_label=899, count_filenames=1704]
# [DEBUG] Comparing filename: '5693_ang20231122t080745_002.tif' (filename_num=5693) with label_num=5693 [count_label=899, count_filenames=1705]
# [DEBUG] Comparing filename: '5693_ang20231110t082850_006.tif' (filename_num=5693) with label_num=5693 [count_label=899, count_filenames=1706]
# [DEBUG] Comparing filename: '5695_ang20231122t084424_002.tif' (filename_num=5695) with label_num=5693 [count_label=899, count_filenames=1707]
# [DEBUG] Comparing filename: '5695_ang20231122t084424_002.tif' (filename_num=5695) with label_num=5695 [count_label=900, count_filenames=1707]
# [DEBUG] Comparing filename: '5695_ang20231110t080035_000.tif' (filename_num=5695) with label_num=5695 [count_label=900, count_filenames=1708]
# [DEBUG] Comparing filename: '5695_ang20231122t083046_015.tif' (filename_num=5695) with label_num=5695 [count_label=900, count_filenames=1709]
# [DEBUG] Comparing filename: '5696_ang20231110t080035_000.tif' (filename_num=5696) with label_num=5695 [count_label=900, count_filenames=1710]
# [DEBUG] Comparing filename: '5696_ang20231110t080035_000.tif' (filename_num=5696) with label_num=5696 [count_label=901, count_filenames=1710]
# [DEBUG] Comparing filename: '5697_ang20231110t080035_000.tif' (filename_num=5697) with label_num=5696 [count_label=901, count_filenames=1711]
# [DEBUG] Comparing filename: '5697_ang20231110t080035_000.tif' (filename_num=5697) with label_num=5697 [count_label=902, count_filenames=1711]
# [DEBUG] Comparing filename: '5697_ang20231122t084424_002.tif' (filename_num=5697) with label_num=5697 [count_label=902, count_filenames=1712]
# [DEBUG] Comparing filename: '5697_ang20231110t074442_015.tif' (filename_num=5697) with label_num=5697 [count_label=902, count_filenames=1713]
# [DEBUG] Comparing filename: '5698_ang20231122t084424_001.tif' (filename_num=5698) with label_num=5697 [count_label=902, count_filenames=1714]
# [DEBUG] Comparing filename: '5698_ang20231122t084424_001.tif' (filename_num=5698) with label_num=5698 [count_label=903, count_filenames=1714]
# [DEBUG] Comparing filename: '5698_ang20231110t074442_015.tif' (filename_num=5698) with label_num=5698 [count_label=903, count_filenames=1715]
# [DEBUG] Comparing filename: '5698_ang20231110t080035_000.tif' (filename_num=5698) with label_num=5698 [count_label=903, count_filenames=1716]
# [DEBUG] Comparing filename: '5699_ang20231122t084424_002.tif' (filename_num=5699) with label_num=5698 [count_label=903, count_filenames=1717]
# [DEBUG] Comparing filename: '5699_ang20231122t084424_002.tif' (filename_num=5699) with label_num=5699 [count_label=904, count_filenames=1717]
# [DEBUG] Comparing filename: '5699_ang20231122t083046_015.tif' (filename_num=5699) with label_num=5699 [count_label=904, count_filenames=1718]
# [DEBUG] Comparing filename: '5699_ang20231110t074442_015.tif' (filename_num=5699) with label_num=5699 [count_label=904, count_filenames=1719]
# [DEBUG] Comparing filename: '5700_ang20231122t091604_001.tif' (filename_num=5700) with label_num=5699 [count_label=904, count_filenames=1720]
# [DEBUG] Comparing filename: '5700_ang20231122t091604_001.tif' (filename_num=5700) with label_num=5700 [count_label=905, count_filenames=1720]
# [DEBUG] Comparing filename: '5700_ang20231110t073153_001.tif' (filename_num=5700) with label_num=5700 [count_label=905, count_filenames=1721]
# [DEBUG] Comparing filename: '5701_ang20231110t080035_000.tif' (filename_num=5701) with label_num=5700 [count_label=905, count_filenames=1722]
# [DEBUG] Comparing filename: '5701_ang20231110t080035_000.tif' (filename_num=5701) with label_num=5701 [count_label=906, count_filenames=1722]
# [DEBUG] Comparing filename: '5702_ang20231122t084424_001.tif' (filename_num=5702) with label_num=5701 [count_label=906, count_filenames=1723]
# [DEBUG] Comparing filename: '5702_ang20231122t084424_001.tif' (filename_num=5702) with label_num=5702 [count_label=907, count_filenames=1723]
# [DEBUG] Comparing filename: '5702_ang20231110t074442_015.tif' (filename_num=5702) with label_num=5702 [count_label=907, count_filenames=1724]
# [DEBUG] Comparing filename: '5706_ang20231110t073153_000.tif' (filename_num=5706) with label_num=5702 [count_label=907, count_filenames=1725]
# [DEBUG] Comparing filename: '5706_ang20231110t073153_000.tif' (filename_num=5706) with label_num=5703 [count_label=908, count_filenames=1725]
# [DEBUG] Comparing filename: '5706_ang20231110t073153_000.tif' (filename_num=5706) with label_num=5704 [count_label=909, count_filenames=1725]
# [DEBUG] Comparing filename: '5706_ang20231110t073153_000.tif' (filename_num=5706) with label_num=5706 [count_label=910, count_filenames=1725]
# [DEBUG] Comparing filename: '5706_ang20231122t091604_002.tif' (filename_num=5706) with label_num=5706 [count_label=910, count_filenames=1726]
# [DEBUG] Comparing filename: '5706_ang20231122t090228_016.tif' (filename_num=5706) with label_num=5706 [count_label=910, count_filenames=1727]
# [DEBUG] Comparing filename: '5707_ang20231110t074442_011.tif' (filename_num=5707) with label_num=5706 [count_label=910, count_filenames=1728]
# [DEBUG] Comparing filename: '5707_ang20231110t074442_011.tif' (filename_num=5707) with label_num=5707 [count_label=911, count_filenames=1728]
# [DEBUG] Comparing filename: '5709_ang20231110t074442_011.tif' (filename_num=5709) with label_num=5707 [count_label=911, count_filenames=1729]
# [DEBUG] Comparing filename: '5709_ang20231110t074442_011.tif' (filename_num=5709) with label_num=5709 [count_label=912, count_filenames=1729]
# [DEBUG] Comparing filename: '5710_ang20231110t074442_011.tif' (filename_num=5710) with label_num=5709 [count_label=912, count_filenames=1730]
# [DEBUG] Comparing filename: '5710_ang20231110t074442_011.tif' (filename_num=5710) with label_num=5710 [count_label=913, count_filenames=1730]
# [DEBUG] Comparing filename: '5711_ang20231110t074442_011.tif' (filename_num=5711) with label_num=5710 [count_label=913, count_filenames=1731]
# [DEBUG] Comparing filename: '5711_ang20231110t074442_011.tif' (filename_num=5711) with label_num=5711 [count_label=914, count_filenames=1731]
# [DEBUG] Comparing filename: '5713_ang20231110t073153_004.tif' (filename_num=5713) with label_num=5711 [count_label=914, count_filenames=1732]
# [DEBUG] Comparing filename: '5713_ang20231110t073153_004.tif' (filename_num=5713) with label_num=5713 [count_label=915, count_filenames=1732]
# [DEBUG] Comparing filename: '5718_ang20231029t123011_009.tif' (filename_num=5718) with label_num=5713 [count_label=915, count_filenames=1733]
# [DEBUG] Comparing filename: '5718_ang20231029t123011_009.tif' (filename_num=5718) with label_num=5718 [count_label=916, count_filenames=1733]
# [DEBUG] Comparing filename: '5718_ang20231029t120919_006.tif' (filename_num=5718) with label_num=5718 [count_label=916, count_filenames=1734]
# [DEBUG] Comparing filename: '5719_ang20231029t123011_009.tif' (filename_num=5719) with label_num=5718 [count_label=916, count_filenames=1735]
# [DEBUG] Comparing filename: '5719_ang20231029t123011_009.tif' (filename_num=5719) with label_num=5719 [count_label=917, count_filenames=1735]
# [DEBUG] Comparing filename: '5719_ang20231029t120919_006.tif' (filename_num=5719) with label_num=5719 [count_label=917, count_filenames=1736]
# [DEBUG] Comparing filename: '5720_ang20231029t120919_006.tif' (filename_num=5720) with label_num=5719 [count_label=917, count_filenames=1737]
# [DEBUG] Comparing filename: '5720_ang20231029t120919_006.tif' (filename_num=5720) with label_num=5720 [count_label=918, count_filenames=1737]
# [DEBUG] Comparing filename: '5721_ang20231029t123011_009.tif' (filename_num=5721) with label_num=5720 [count_label=918, count_filenames=1738]
# [DEBUG] Comparing filename: '5721_ang20231029t123011_009.tif' (filename_num=5721) with label_num=5721 [count_label=919, count_filenames=1738]
# [DEBUG] Comparing filename: '5721_ang20231022t092801_008.tif' (filename_num=5721) with label_num=5721 [count_label=919, count_filenames=1739]
# [DEBUG] Comparing filename: '5722_ang20231029t120919_006.tif' (filename_num=5722) with label_num=5721 [count_label=919, count_filenames=1740]
# [DEBUG] Comparing filename: '5722_ang20231029t120919_006.tif' (filename_num=5722) with label_num=5722 [count_label=920, count_filenames=1740]
# [DEBUG] Comparing filename: '5722_ang20231029t123011_009.tif' (filename_num=5722) with label_num=5722 [count_label=920, count_filenames=1741]
# [DEBUG] Comparing filename: '5723_ang20231029t120919_006.tif' (filename_num=5723) with label_num=5722 [count_label=920, count_filenames=1742]
# [DEBUG] Comparing filename: '5723_ang20231029t120919_006.tif' (filename_num=5723) with label_num=5723 [count_label=921, count_filenames=1742]
# [DEBUG] Comparing filename: '5723_ang20231029t123011_009.tif' (filename_num=5723) with label_num=5723 [count_label=921, count_filenames=1743]
# [DEBUG] Comparing filename: '5724_ang20231110t073153_000.tif' (filename_num=5724) with label_num=5723 [count_label=921, count_filenames=1744]
# [DEBUG] Comparing filename: '5724_ang20231110t073153_000.tif' (filename_num=5724) with label_num=5724 [count_label=922, count_filenames=1744]
# [DEBUG] Comparing filename: '5724_ang20231122t091604_001.tif' (filename_num=5724) with label_num=5724 [count_label=922, count_filenames=1745]
# [DEBUG] Comparing filename: '5725_ang20231110t073153_001.tif' (filename_num=5725) with label_num=5724 [count_label=922, count_filenames=1746]
# [DEBUG] Comparing filename: '5725_ang20231110t073153_001.tif' (filename_num=5725) with label_num=5725 [count_label=923, count_filenames=1746]
# [DEBUG] Comparing filename: '5725_ang20231122t091604_001.tif' (filename_num=5725) with label_num=5725 [count_label=923, count_filenames=1747]
# [DEBUG] Comparing filename: '5728_ang20231110t073153_002.tif' (filename_num=5728) with label_num=5725 [count_label=923, count_filenames=1748]
# [DEBUG] Comparing filename: '5728_ang20231110t073153_002.tif' (filename_num=5728) with label_num=5728 [count_label=924, count_filenames=1748]
# [DEBUG] Comparing filename: '5728_ang20231025t084701_001.tif' (filename_num=5728) with label_num=5728 [count_label=924, count_filenames=1749]
# [DEBUG] Comparing filename: '5728_ang20231116t070033_003.tif' (filename_num=5728) with label_num=5728 [count_label=924, count_filenames=1750]
# [DEBUG] Comparing filename: '5729_ang20231110t073153_002.tif' (filename_num=5729) with label_num=5728 [count_label=924, count_filenames=1751]
# [DEBUG] Comparing filename: '5729_ang20231110t073153_002.tif' (filename_num=5729) with label_num=5729 [count_label=925, count_filenames=1751]
# [DEBUG] Comparing filename: '5729_ang20231025t084701_001.tif' (filename_num=5729) with label_num=5729 [count_label=925, count_filenames=1752]
# [DEBUG] Comparing filename: '5729_ang20231110t071541_010.tif' (filename_num=5729) with label_num=5729 [count_label=925, count_filenames=1753]
# [DEBUG] Comparing filename: '5738_ang20231110t073153_003.tif' (filename_num=5738) with label_num=5729 [count_label=925, count_filenames=1754]
# [DEBUG] Comparing filename: '5738_ang20231110t073153_003.tif' (filename_num=5738) with label_num=5738 [count_label=926, count_filenames=1754]
# [DEBUG] Comparing filename: '5740_ang20231109t123229_002.tif' (filename_num=5740) with label_num=5738 [count_label=926, count_filenames=1755]
# [DEBUG] Comparing filename: '5740_ang20231109t123229_002.tif' (filename_num=5740) with label_num=5740 [count_label=927, count_filenames=1755]
# [DEBUG] Comparing filename: '5741_ang20231109t123229_002.tif' (filename_num=5741) with label_num=5740 [count_label=927, count_filenames=1756]
# [DEBUG] Comparing filename: '5741_ang20231109t123229_002.tif' (filename_num=5741) with label_num=5741 [count_label=928, count_filenames=1756]
# [DEBUG] Comparing filename: '5743_ang20231109t101807_017.tif' (filename_num=5743) with label_num=5741 [count_label=928, count_filenames=1757]
# [DEBUG] Comparing filename: '5743_ang20231109t101807_017.tif' (filename_num=5743) with label_num=5743 [count_label=929, count_filenames=1757]
# [DEBUG] Comparing filename: '5743_ang20231109t103404_004.tif' (filename_num=5743) with label_num=5743 [count_label=929, count_filenames=1758]
# [DEBUG] Comparing filename: '5744_ang20231109t101807_017.tif' (filename_num=5744) with label_num=5743 [count_label=929, count_filenames=1759]
# [DEBUG] Comparing filename: '5744_ang20231109t101807_017.tif' (filename_num=5744) with label_num=5744 [count_label=930, count_filenames=1759]
# [DEBUG] Comparing filename: '5744_ang20231109t103404_005.tif' (filename_num=5744) with label_num=5744 [count_label=930, count_filenames=1760]
# [DEBUG] Comparing filename: '5745_ang20231109t103404_004.tif' (filename_num=5745) with label_num=5744 [count_label=930, count_filenames=1761]
# [DEBUG] Comparing filename: '5745_ang20231109t103404_004.tif' (filename_num=5745) with label_num=5745 [count_label=931, count_filenames=1761]
# [DEBUG] Comparing filename: '5745_ang20231110t101341_004.tif' (filename_num=5745) with label_num=5745 [count_label=931, count_filenames=1762]
# [DEBUG] Comparing filename: '5757_ang20231109t103404_012.tif' (filename_num=5757) with label_num=5745 [count_label=931, count_filenames=1763]
# [DEBUG] Comparing filename: '5757_ang20231109t103404_012.tif' (filename_num=5757) with label_num=5757 [count_label=932, count_filenames=1763]
# [DEBUG] Comparing filename: '5757_ang20231109t105153_004.tif' (filename_num=5757) with label_num=5757 [count_label=932, count_filenames=1764]
# [DEBUG] Comparing filename: '5757_ang20231110t101341_013.tif' (filename_num=5757) with label_num=5757 [count_label=932, count_filenames=1765]
# [DEBUG] Comparing filename: '5758_ang20231109t103404_012.tif' (filename_num=5758) with label_num=5757 [count_label=932, count_filenames=1766]
# [DEBUG] Comparing filename: '5758_ang20231109t103404_012.tif' (filename_num=5758) with label_num=5758 [count_label=933, count_filenames=1766]
# [DEBUG] Comparing filename: '5764_ang20231110t073153_008.tif' (filename_num=5764) with label_num=5758 [count_label=933, count_filenames=1767]
# [DEBUG] Comparing filename: '5764_ang20231110t073153_008.tif' (filename_num=5764) with label_num=5764 [count_label=934, count_filenames=1767]
# [DEBUG] Comparing filename: '5767_ang20231025t084701_001.tif' (filename_num=5767) with label_num=5764 [count_label=934, count_filenames=1768]
# [DEBUG] Comparing filename: '5767_ang20231025t084701_001.tif' (filename_num=5767) with label_num=5767 [count_label=935, count_filenames=1768]
# [DEBUG] Comparing filename: '5767_ang20231110t071541_011.tif' (filename_num=5767) with label_num=5767 [count_label=935, count_filenames=1769]
# [DEBUG] Comparing filename: '5767_ang20231122t091604_000.tif' (filename_num=5767) with label_num=5767 [count_label=935, count_filenames=1770]
# [DEBUG] Comparing filename: '5771_ang20231109t095948_002.tif' (filename_num=5771) with label_num=5767 [count_label=935, count_filenames=1771]
# [DEBUG] Comparing filename: '5771_ang20231109t095948_002.tif' (filename_num=5771) with label_num=5771 [count_label=936, count_filenames=1771]
# [DEBUG] Comparing filename: '5772_ang20231109t095948_002.tif' (filename_num=5772) with label_num=5771 [count_label=936, count_filenames=1772]
# [DEBUG] Comparing filename: '5772_ang20231109t095948_002.tif' (filename_num=5772) with label_num=5772 [count_label=937, count_filenames=1772]
# [DEBUG] Comparing filename: '5772_ang20231109t094509_013.tif' (filename_num=5772) with label_num=5772 [count_label=937, count_filenames=1773]
# [DEBUG] Comparing filename: '5773_ang20231109t123229_002.tif' (filename_num=5773) with label_num=5772 [count_label=937, count_filenames=1774]
# [DEBUG] Comparing filename: '5773_ang20231109t123229_002.tif' (filename_num=5773) with label_num=5773 [count_label=938, count_filenames=1774]
# [DEBUG] Comparing filename: '5773_ang20231109t122224_006.tif' (filename_num=5773) with label_num=5773 [count_label=938, count_filenames=1775]
# [DEBUG] Comparing filename: '5774_ang20231109t123229_002.tif' (filename_num=5774) with label_num=5773 [count_label=938, count_filenames=1776]
# [DEBUG] Comparing filename: '5774_ang20231109t123229_002.tif' (filename_num=5774) with label_num=5774 [count_label=939, count_filenames=1776]
# [DEBUG] Comparing filename: '5774_ang20231109t122224_006.tif' (filename_num=5774) with label_num=5774 [count_label=939, count_filenames=1777]
# [DEBUG] Comparing filename: '5777_ang20231109t123229_002.tif' (filename_num=5777) with label_num=5774 [count_label=939, count_filenames=1778]
# [DEBUG] Comparing filename: '5777_ang20231109t123229_002.tif' (filename_num=5777) with label_num=5777 [count_label=940, count_filenames=1778]
# [DEBUG] Comparing filename: '5778_ang20231022t113923_012.tif' (filename_num=5778) with label_num=5777 [count_label=940, count_filenames=1779]
# [DEBUG] Comparing filename: '5778_ang20231022t113923_012.tif' (filename_num=5778) with label_num=5778 [count_label=941, count_filenames=1779]
# [DEBUG] Comparing filename: '5779_ang20231022t113923_012.tif' (filename_num=5779) with label_num=5778 [count_label=941, count_filenames=1780]
# [DEBUG] Comparing filename: '5779_ang20231022t113923_012.tif' (filename_num=5779) with label_num=5779 [count_label=942, count_filenames=1780]
# [DEBUG] Comparing filename: '5786_ang20231109t095948_002.tif' (filename_num=5786) with label_num=5779 [count_label=942, count_filenames=1781]
# [DEBUG] Comparing filename: '5786_ang20231109t095948_002.tif' (filename_num=5786) with label_num=5786 [count_label=943, count_filenames=1781]
# [DEBUG] Comparing filename: '5786_ang20231109t094509_013.tif' (filename_num=5786) with label_num=5786 [count_label=943, count_filenames=1782]
# [DEBUG] Comparing filename: '5787_ang20231109t095948_002.tif' (filename_num=5787) with label_num=5786 [count_label=943, count_filenames=1783]
# [DEBUG] Comparing filename: '5787_ang20231109t095948_002.tif' (filename_num=5787) with label_num=5787 [count_label=944, count_filenames=1783]
# [DEBUG] Comparing filename: '5788_ang20231109t094509_013.tif' (filename_num=5788) with label_num=5787 [count_label=944, count_filenames=1784]
# [DEBUG] Comparing filename: '5788_ang20231109t094509_013.tif' (filename_num=5788) with label_num=5788 [count_label=945, count_filenames=1784]
# [DEBUG] Comparing filename: '5789_ang20231109t095948_003.tif' (filename_num=5789) with label_num=5788 [count_label=945, count_filenames=1785]
# [DEBUG] Comparing filename: '5789_ang20231109t095948_003.tif' (filename_num=5789) with label_num=5789 [count_label=946, count_filenames=1785]
# [DEBUG] Comparing filename: '5790_ang20231029t120919_006.tif' (filename_num=5790) with label_num=5789 [count_label=946, count_filenames=1786]
# [DEBUG] Comparing filename: '5790_ang20231029t120919_006.tif' (filename_num=5790) with label_num=5790 [count_label=947, count_filenames=1786]
# [DEBUG] Comparing filename: '5790_ang20231029t114806_010.tif' (filename_num=5790) with label_num=5790 [count_label=947, count_filenames=1787]
# [DEBUG] Comparing filename: '5791_ang20231029t120919_006.tif' (filename_num=5791) with label_num=5790 [count_label=947, count_filenames=1788]
# [DEBUG] Comparing filename: '5791_ang20231029t120919_006.tif' (filename_num=5791) with label_num=5791 [count_label=948, count_filenames=1788]
# [DEBUG] Comparing filename: '5791_ang20231029t114806_010.tif' (filename_num=5791) with label_num=5791 [count_label=948, count_filenames=1789]
# [DEBUG] Comparing filename: '5797_ang20231110t080035_001.tif' (filename_num=5797) with label_num=5791 [count_label=948, count_filenames=1790]
# [DEBUG] Comparing filename: '5797_ang20231110t080035_001.tif' (filename_num=5797) with label_num=5797 [count_label=949, count_filenames=1790]
# [DEBUG] Comparing filename: '5802_ang20231025t084701_001.tif' (filename_num=5802) with label_num=5797 [count_label=949, count_filenames=1791]
# [DEBUG] Comparing filename: '5802_ang20231025t084701_001.tif' (filename_num=5802) with label_num=5802 [count_label=950, count_filenames=1791]
# [DEBUG] Comparing filename: '5802_ang20231110t071541_011.tif' (filename_num=5802) with label_num=5802 [count_label=950, count_filenames=1792]
# [DEBUG] Comparing filename: '5802_ang20231116t070033_002.tif' (filename_num=5802) with label_num=5802 [count_label=950, count_filenames=1793]
# [DEBUG] Comparing filename: '5802_ang20231122t091604_000.tif' (filename_num=5802) with label_num=5802 [count_label=950, count_filenames=1794]
# [DEBUG] Comparing filename: '5841_ang20231025t084701_001.tif' (filename_num=5841) with label_num=5802 [count_label=950, count_filenames=1795]
# [DEBUG] Comparing filename: '5841_ang20231025t084701_001.tif' (filename_num=5841) with label_num=5841 [count_label=951, count_filenames=1795]
# [DEBUG] Comparing filename: '5841_ang20231110t071541_011.tif' (filename_num=5841) with label_num=5841 [count_label=951, count_filenames=1796]
# [DEBUG] Comparing filename: '5841_ang20231122t091604_000.tif' (filename_num=5841) with label_num=5841 [count_label=951, count_filenames=1797]
# [DEBUG] Comparing filename: '5841_ang20231110t073153_001.tif' (filename_num=5841) with label_num=5841 [count_label=951, count_filenames=1798]
# [DEBUG] Comparing filename: '5866_ang20231110t073153_003.tif' (filename_num=5866) with label_num=5841 [count_label=951, count_filenames=1799]
# [DEBUG] Comparing filename: '5866_ang20231110t073153_003.tif' (filename_num=5866) with label_num=5866 [count_label=952, count_filenames=1799]
# [DEBUG] Comparing filename: '5866_ang20231110t074442_012.tif' (filename_num=5866) with label_num=5866 [count_label=952, count_filenames=1800]
# [DEBUG] Comparing filename: '5879_ang20231110t071541_011.tif' (filename_num=5879) with label_num=5866 [count_label=952, count_filenames=1801]
# [DEBUG] Comparing filename: '5879_ang20231110t071541_011.tif' (filename_num=5879) with label_num=5879 [count_label=953, count_filenames=1801]
# [DEBUG] Comparing filename: '5880_ang20231122t091604_001.tif' (filename_num=5880) with label_num=5879 [count_label=953, count_filenames=1802]
# [DEBUG] Comparing filename: '5880_ang20231122t091604_001.tif' (filename_num=5880) with label_num=5880 [count_label=954, count_filenames=1802]
# [DEBUG] Comparing filename: '5880_ang20231110t071541_011.tif' (filename_num=5880) with label_num=5880 [count_label=954, count_filenames=1803]
# [DEBUG] Comparing filename: '5881_ang20231122t091604_001.tif' (filename_num=5881) with label_num=5880 [count_label=954, count_filenames=1804]
# [DEBUG] Comparing filename: '5881_ang20231122t091604_001.tif' (filename_num=5881) with label_num=5881 [count_label=955, count_filenames=1804]
# [DEBUG] Comparing filename: '5881_ang20231110t071541_011.tif' (filename_num=5881) with label_num=5881 [count_label=955, count_filenames=1805]
# [DEBUG] Comparing filename: '5882_ang20231110t071541_011.tif' (filename_num=5882) with label_num=5881 [count_label=955, count_filenames=1806]
# [DEBUG] Comparing filename: '5882_ang20231110t071541_011.tif' (filename_num=5882) with label_num=5882 [count_label=956, count_filenames=1806]
# [DEBUG] Comparing filename: '5885_ang20231109t103404_015.tif' (filename_num=5885) with label_num=5882 [count_label=956, count_filenames=1807]
# [DEBUG] Comparing filename: '5885_ang20231109t103404_015.tif' (filename_num=5885) with label_num=5885 [count_label=957, count_filenames=1807]
# [DEBUG] Comparing filename: '5885_ang20231109t101807_003.tif' (filename_num=5885) with label_num=5885 [count_label=957, count_filenames=1808]
# [DEBUG] Comparing filename: '5886_ang20231109t103404_015.tif' (filename_num=5886) with label_num=5885 [count_label=957, count_filenames=1809]
# [DEBUG] Comparing filename: '5886_ang20231109t103404_015.tif' (filename_num=5886) with label_num=5886 [count_label=958, count_filenames=1809]
# [DEBUG] Comparing filename: '5886_ang20231109t105153_001.tif' (filename_num=5886) with label_num=5886 [count_label=958, count_filenames=1810]
# [DEBUG] Comparing filename: '5887_ang20231109t105153_001.tif' (filename_num=5887) with label_num=5886 [count_label=958, count_filenames=1811]
# [DEBUG] Comparing filename: '5887_ang20231109t105153_001.tif' (filename_num=5887) with label_num=5887 [count_label=959, count_filenames=1811]
# [DEBUG] Comparing filename: '5887_ang20231109t103404_015.tif' (filename_num=5887) with label_num=5887 [count_label=959, count_filenames=1812]
# [DEBUG] Comparing filename: '5888_ang20231025t060824_001.tif' (filename_num=5888) with label_num=5887 [count_label=959, count_filenames=1813]
# [DEBUG] Comparing filename: '5888_ang20231025t060824_001.tif' (filename_num=5888) with label_num=5888 [count_label=960, count_filenames=1813]
# [DEBUG] Comparing filename: '5888_ang20231110t071541_008.tif' (filename_num=5888) with label_num=5888 [count_label=960, count_filenames=1814]
# [DEBUG] Comparing filename: '5889_ang20231025t060824_001.tif' (filename_num=5889) with label_num=5888 [count_label=960, count_filenames=1815]
# [DEBUG] Comparing filename: '5889_ang20231025t060824_001.tif' (filename_num=5889) with label_num=5889 [count_label=961, count_filenames=1815]
# [DEBUG] Comparing filename: '5889_ang20231110t071541_008.tif' (filename_num=5889) with label_num=5889 [count_label=961, count_filenames=1816]
# [DEBUG] Comparing filename: '5899_ang20231110t073153_009.tif' (filename_num=5899) with label_num=5889 [count_label=961, count_filenames=1817]
# [DEBUG] Comparing filename: '5899_ang20231110t073153_009.tif' (filename_num=5899) with label_num=5899 [count_label=962, count_filenames=1817]
# [DEBUG] Comparing filename: '5899_ang20231110t071541_004.tif' (filename_num=5899) with label_num=5899 [count_label=962, count_filenames=1818]
# [DEBUG] Comparing filename: '5900_ang20231110t073153_009.tif' (filename_num=5900) with label_num=5899 [count_label=962, count_filenames=1819]
# [DEBUG] Comparing filename: '5900_ang20231110t073153_009.tif' (filename_num=5900) with label_num=5900 [count_label=963, count_filenames=1819]
# [DEBUG] Comparing filename: '5900_ang20231110t074442_005.tif' (filename_num=5900) with label_num=5900 [count_label=963, count_filenames=1820]
# [DEBUG] Comparing filename: '5902_ang20231122t094710_000.tif' (filename_num=5902) with label_num=5900 [count_label=963, count_filenames=1821]
# [DEBUG] Comparing filename: '5902_ang20231122t094710_000.tif' (filename_num=5902) with label_num=5902 [count_label=964, count_filenames=1821]
# [DEBUG] Comparing filename: '5902_ang20231110t071541_011.tif' (filename_num=5902) with label_num=5902 [count_label=964, count_filenames=1822]
# [DEBUG] Comparing filename: '5902_ang20231110t070302_000.tif' (filename_num=5902) with label_num=5902 [count_label=964, count_filenames=1823]
# ...
# [DEBUG] Comparing filename: '28115_ang20231029t114806_014.tif' (filename_num=28115) with label_num=28111 [count_label=2387, count_filenames=4953]
# [DEBUG] Comparing filename: '28115_ang20231029t114806_014.tif' (filename_num=28115) with label_num=28115 [count_label=2388, count_filenames=4953]
# [DEBUG] Comparing filename: '28115_ang20231126t114026_003.tif' (filename_num=28115) with label_num=28115 [count_label=2388, count_filenames=4954]
# [DEBUG] Comparing filename: '28120_ang20231029t110711_014.tif' (filename_num=28120) with label_num=28115 [count_label=2388, count_filenames=4955]
# [DEBUG] Comparing filename: '28120_ang20231029t110711_014.tif' (filename_num=28120) with label_num=28120 [count_label=2389, count_filenames=4955]
# [DEBUG] Comparing filename: '28125_ang20231022t113923_016.tif' (filename_num=28125) with label_num=28120 [count_label=2389, count_filenames=4956]
# [DEBUG] Comparing filename: '28125_ang20231022t113923_016.tif' (filename_num=28125) with label_num=28125 [count_label=2390, count_filenames=4956]
# [DEBUG] Comparing filename: '28183_ang20231022t133049_000.tif' (filename_num=28183) with label_num=28125 [count_label=2390, count_filenames=4957]
# [DEBUG] Comparing filename: '28183_ang20231022t133049_000.tif' (filename_num=28183) with label_num=28183 [count_label=2391, count_filenames=4957]
# [DEBUG] Comparing filename: '28183_ang20231022t130705_016.tif' (filename_num=28183) with label_num=28183 [count_label=2391, count_filenames=4958]
# [DEBUG] Comparing filename: '28184_ang20231022t103357_000.tif' (filename_num=28184) with label_num=28183 [count_label=2391, count_filenames=4959]
# [DEBUG] Comparing filename: '28184_ang20231022t103357_000.tif' (filename_num=28184) with label_num=28184 [count_label=2392, count_filenames=4959]
# [DEBUG] Comparing filename: '28184_ang20231022t101052_015.tif' (filename_num=28184) with label_num=28184 [count_label=2392, count_filenames=4960]
# [DEBUG] Comparing filename: '28201_ang20231022t124546_001.tif' (filename_num=28201) with label_num=28184 [count_label=2392, count_filenames=4961]
# [DEBUG] Comparing filename: '28201_ang20231022t124546_001.tif' (filename_num=28201) with label_num=28201 [count_label=2393, count_filenames=4961]
# [DEBUG] Comparing filename: '28201_ang20231022t130705_016.tif' (filename_num=28201) with label_num=28201 [count_label=2393, count_filenames=4962]
# [DEBUG] Comparing filename: '28207_ang20231022t124546_001.tif' (filename_num=28207) with label_num=28201 [count_label=2393, count_filenames=4963]
# [DEBUG] Comparing filename: '28207_ang20231022t124546_001.tif' (filename_num=28207) with label_num=28207 [count_label=2394, count_filenames=4963]
# [DEBUG] Comparing filename: '28207_ang20231022t130705_016.tif' (filename_num=28207) with label_num=28207 [count_label=2394, count_filenames=4964]
# [DEBUG] Comparing filename: '28221_ang20231117t135719_011.tif' (filename_num=28221) with label_num=28207 [count_label=2394, count_filenames=4965]
# [DEBUG] Comparing filename: '28221_ang20231117t135719_011.tif' (filename_num=28221) with label_num=28221 [count_label=2395, count_filenames=4965]
# [DEBUG] Comparing filename: '28221_ang20231025t094130_019.tif' (filename_num=28221) with label_num=28221 [count_label=2395, count_filenames=4966]
# [DEBUG] Comparing filename: '28221_ang20231025t092131_000.tif' (filename_num=28221) with label_num=28221 [count_label=2395, count_filenames=4967]
# [DEBUG] Comparing filename: '28221_ang20231108t133101_000.tif' (filename_num=28221) with label_num=28221 [count_label=2395, count_filenames=4968]
# [DEBUG] Comparing filename: '28221_ang20231108t140012_000.tif' (filename_num=28221) with label_num=28221 [count_label=2395, count_filenames=4969]
# [DEBUG] Comparing filename: '28221_ang20231025t100314_001.tif' (filename_num=28221) with label_num=28221 [count_label=2395, count_filenames=4970]
# [DEBUG] Comparing filename: '28276_ang20231117t133944_001.tif' (filename_num=28276) with label_num=28221 [count_label=2395, count_filenames=4971]
# [DEBUG] Comparing filename: '28276_ang20231117t133944_001.tif' (filename_num=28276) with label_num=28276 [count_label=2396, count_filenames=4971]
# [DEBUG] Comparing filename: '28276_ang20231117t132119_014.tif' (filename_num=28276) with label_num=28276 [count_label=2396, count_filenames=4972]
# [DEBUG] Comparing filename: '28277_ang20231117t133944_001.tif' (filename_num=28277) with label_num=28276 [count_label=2396, count_filenames=4973]
# [DEBUG] Comparing filename: '28277_ang20231117t133944_001.tif' (filename_num=28277) with label_num=28277 [count_label=2397, count_filenames=4973]
# [DEBUG] Comparing filename: '28282_ang20231117t133944_002.tif' (filename_num=28282) with label_num=28277 [count_label=2397, count_filenames=4974]
# [DEBUG] Comparing filename: '28282_ang20231117t133944_002.tif' (filename_num=28282) with label_num=28282 [count_label=2398, count_filenames=4974]
# [DEBUG] Comparing filename: '28301_ang20231117t133944_002.tif' (filename_num=28301) with label_num=28282 [count_label=2398, count_filenames=4975]
# [DEBUG] Comparing filename: '28301_ang20231117t133944_002.tif' (filename_num=28301) with label_num=28301 [count_label=2399, count_filenames=4975]
# [DEBUG] Comparing filename: '28301_ang20231117t132119_012.tif' (filename_num=28301) with label_num=28301 [count_label=2399, count_filenames=4976]
# [DEBUG] Comparing filename: '28310_ang20231117t135719_007.tif' (filename_num=28310) with label_num=28301 [count_label=2399, count_filenames=4977]
# [DEBUG] Comparing filename: '28310_ang20231117t135719_007.tif' (filename_num=28310) with label_num=28310 [count_label=2400, count_filenames=4977]
# [DEBUG] Comparing filename: '28317_ang20231117t130605_002.tif' (filename_num=28317) with label_num=28310 [count_label=2400, count_filenames=4978]
# [DEBUG] Comparing filename: '28317_ang20231117t130605_002.tif' (filename_num=28317) with label_num=28317 [count_label=2401, count_filenames=4978]
# [DEBUG] Comparing filename: '28336_ang20231117t130605_004.tif' (filename_num=28336) with label_num=28317 [count_label=2401, count_filenames=4979]
# [DEBUG] Comparing filename: '28336_ang20231117t130605_004.tif' (filename_num=28336) with label_num=28336 [count_label=2402, count_filenames=4979]
# [DEBUG] Comparing filename: '28336_ang20231117t132119_011.tif' (filename_num=28336) with label_num=28336 [count_label=2402, count_filenames=4980]
# [DEBUG] Comparing filename: '28340_ang20231117t132119_011.tif' (filename_num=28340) with label_num=28336 [count_label=2402, count_filenames=4981]
# [DEBUG] Comparing filename: '28340_ang20231117t132119_011.tif' (filename_num=28340) with label_num=28340 [count_label=2403, count_filenames=4981]
# [DEBUG] Comparing filename: '28340_ang20231117t130605_003.tif' (filename_num=28340) with label_num=28340 [count_label=2403, count_filenames=4982]
# [DEBUG] Comparing filename: '28360_ang20231117t124818_010.tif' (filename_num=28360) with label_num=28340 [count_label=2403, count_filenames=4983]
# [DEBUG] Comparing filename: '28360_ang20231117t124818_010.tif' (filename_num=28360) with label_num=28360 [count_label=2404, count_filenames=4983]
# [DEBUG] Comparing filename: '28360_ang20231117t130605_004.tif' (filename_num=28360) with label_num=28360 [count_label=2404, count_filenames=4984]
# [DEBUG] Comparing filename: '28361_ang20231117t124818_012.tif' (filename_num=28361) with label_num=28360 [count_label=2404, count_filenames=4985]
# [DEBUG] Comparing filename: '28361_ang20231117t124818_012.tif' (filename_num=28361) with label_num=28361 [count_label=2405, count_filenames=4985]
# [DEBUG] Comparing filename: '28361_ang20231117t123306_002.tif' (filename_num=28361) with label_num=28361 [count_label=2405, count_filenames=4986]
# [DEBUG] Comparing filename: '28374_ang20231117t133944_008.tif' (filename_num=28374) with label_num=28361 [count_label=2405, count_filenames=4987]
# [DEBUG] Comparing filename: '28374_ang20231117t133944_008.tif' (filename_num=28374) with label_num=28374 [count_label=2406, count_filenames=4987]
# [DEBUG] Comparing filename: '28378_ang20231117t133944_008.tif' (filename_num=28378) with label_num=28374 [count_label=2406, count_filenames=4988]
# [DEBUG] Comparing filename: '28378_ang20231117t133944_008.tif' (filename_num=28378) with label_num=28378 [count_label=2407, count_filenames=4988]
# [DEBUG] Comparing filename: '28380_ang20231031t093845_006.tif' (filename_num=28380) with label_num=28378 [count_label=2407, count_filenames=4989]
# [DEBUG] Comparing filename: '28380_ang20231031t093845_006.tif' (filename_num=28380) with label_num=28380 [count_label=2408, count_filenames=4989]
# [DEBUG] Comparing filename: '28380_ang20231117t123306_002.tif' (filename_num=28380) with label_num=28380 [count_label=2408, count_filenames=4990]
# [DEBUG] Comparing filename: '28380_ang20231109t062226_002.tif' (filename_num=28380) with label_num=28380 [count_label=2408, count_filenames=4991]
# [DEBUG] Comparing filename: '28381_ang20231109t062226_002.tif' (filename_num=28381) with label_num=28380 [count_label=2408, count_filenames=4992]
# [DEBUG] Comparing filename: '28381_ang20231109t062226_002.tif' (filename_num=28381) with label_num=28381 [count_label=2409, count_filenames=4992]
# [DEBUG] Comparing filename: '28381_ang20231031t093845_006.tif' (filename_num=28381) with label_num=28381 [count_label=2409, count_filenames=4993]
# [DEBUG] Comparing filename: '28381_ang20231117t123306_002.tif' (filename_num=28381) with label_num=28381 [count_label=2409, count_filenames=4994]
# [DEBUG] Comparing filename: '28382_ang20231117t132119_005.tif' (filename_num=28382) with label_num=28381 [count_label=2409, count_filenames=4995]
# [DEBUG] Comparing filename: '28382_ang20231117t132119_005.tif' (filename_num=28382) with label_num=28382 [count_label=2410, count_filenames=4995]
# [DEBUG] Comparing filename: '28382_ang20231117t133944_008.tif' (filename_num=28382) with label_num=28382 [count_label=2410, count_filenames=4996]
# [DEBUG] Comparing filename: '28413_ang20231031t092656_004.tif' (filename_num=28413) with label_num=28382 [count_label=2410, count_filenames=4997]
# [DEBUG] Comparing filename: '28413_ang20231031t092656_004.tif' (filename_num=28413) with label_num=28413 [count_label=2411, count_filenames=4997]
# [DEBUG] Comparing filename: '28413_ang20231031t093845_005.tif' (filename_num=28413) with label_num=28413 [count_label=2411, count_filenames=4998]
# [DEBUG] Comparing filename: '28413_ang20231109t062226_003.tif' (filename_num=28413) with label_num=28413 [count_label=2411, count_filenames=4999]
# [DEBUG] Comparing filename: '28413_ang20231109t063500_005.tif' (filename_num=28413) with label_num=28413 [count_label=2411, count_filenames=5000]
# [DEBUG] Comparing filename: '28439_ang20231031t093845_002.tif' (filename_num=28439) with label_num=28413 [count_label=2411, count_filenames=5001]
# [DEBUG] Comparing filename: '28439_ang20231031t093845_002.tif' (filename_num=28439) with label_num=28439 [count_label=2412, count_filenames=5001]
# [DEBUG] Comparing filename: '28439_ang20231109t062226_008.tif' (filename_num=28439) with label_num=28439 [count_label=2412, count_filenames=5002]
# [DEBUG] Comparing filename: '28439_ang20231117t123306_006.tif' (filename_num=28439) with label_num=28439 [count_label=2412, count_filenames=5003]
# [DEBUG] Comparing filename: '28448_ang20231031t092656_007.tif' (filename_num=28448) with label_num=28439 [count_label=2412, count_filenames=5004]
# [DEBUG] Comparing filename: '28448_ang20231031t092656_007.tif' (filename_num=28448) with label_num=28448 [count_label=2413, count_filenames=5004]
# [DEBUG] Comparing filename: '28448_ang20231109t063500_003.tif' (filename_num=28448) with label_num=28448 [count_label=2413, count_filenames=5005]
# [DEBUG] Comparing filename: '28452_ang20231031t092656_007.tif' (filename_num=28452) with label_num=28448 [count_label=2413, count_filenames=5006]
# [DEBUG] Comparing filename: '28452_ang20231031t092656_007.tif' (filename_num=28452) with label_num=28452 [count_label=2414, count_filenames=5006]
# [DEBUG] Comparing filename: '28452_ang20231109t063500_003.tif' (filename_num=28452) with label_num=28452 [count_label=2414, count_filenames=5007]
# [DEBUG] Comparing filename: '28460_ang20231109t064755_008.tif' (filename_num=28460) with label_num=28452 [count_label=2414, count_filenames=5008]
# [DEBUG] Comparing filename: '28460_ang20231109t064755_008.tif' (filename_num=28460) with label_num=28460 [count_label=2415, count_filenames=5008]
# [DEBUG] Comparing filename: '28460_ang20231031t092656_008.tif' (filename_num=28460) with label_num=28460 [count_label=2415, count_filenames=5009]
# [DEBUG] Comparing filename: '28460_ang20231031t091505_002.tif' (filename_num=28460) with label_num=28460 [count_label=2415, count_filenames=5010]
# [DEBUG] Comparing filename: '28460_ang20231109t063500_002.tif' (filename_num=28460) with label_num=28460 [count_label=2415, count_filenames=5011]
# [DEBUG] Comparing filename: '28469_ang20231031t093845_000.tif' (filename_num=28469) with label_num=28460 [count_label=2415, count_filenames=5012]
# [DEBUG] Comparing filename: '28469_ang20231031t093845_000.tif' (filename_num=28469) with label_num=28469 [count_label=2416, count_filenames=5012]
# [DEBUG] Comparing filename: '28469_ang20231031t092656_010.tif' (filename_num=28469) with label_num=28469 [count_label=2416, count_filenames=5013]
# [DEBUG] Comparing filename: '28469_ang20231109t062226_009.tif' (filename_num=28469) with label_num=28469 [count_label=2416, count_filenames=5014]
# [DEBUG] Comparing filename: '28469_ang20231109t063500_000.tif' (filename_num=28469) with label_num=28469 [count_label=2416, count_filenames=5015]
# [DEBUG] Comparing filename: '28480_ang20231031t091505_002.tif' (filename_num=28480) with label_num=28469 [count_label=2416, count_filenames=5016]
# [DEBUG] Comparing filename: '28480_ang20231031t091505_002.tif' (filename_num=28480) with label_num=28480 [count_label=2417, count_filenames=5016]
# [DEBUG] Comparing filename: '28480_ang20231109t064755_007.tif' (filename_num=28480) with label_num=28480 [count_label=2417, count_filenames=5017]
# [DEBUG] Comparing filename: '28494_ang20231031t085208_004.tif' (filename_num=28494) with label_num=28480 [count_label=2417, count_filenames=5018]
# [DEBUG] Comparing filename: '28494_ang20231031t085208_004.tif' (filename_num=28494) with label_num=28494 [count_label=2418, count_filenames=5018]
# [DEBUG] Comparing filename: '28494_ang20231031t083942_005.tif' (filename_num=28494) with label_num=28494 [count_label=2418, count_filenames=5019]
# [DEBUG] Comparing filename: '28494_ang20231109t072333_004.tif' (filename_num=28494) with label_num=28494 [count_label=2418, count_filenames=5020]
# [DEBUG] Comparing filename: '28494_ang20231109t071216_005.tif' (filename_num=28494) with label_num=28494 [count_label=2418, count_filenames=5021]
# [DEBUG] Comparing filename: '28496_ang20231031t090334_007.tif' (filename_num=28496) with label_num=28494 [count_label=2418, count_filenames=5022]
# [DEBUG] Comparing filename: '28496_ang20231031t090334_007.tif' (filename_num=28496) with label_num=28496 [count_label=2419, count_filenames=5022]
# [DEBUG] Comparing filename: '28496_ang20231109t065855_003.tif' (filename_num=28496) with label_num=28496 [count_label=2419, count_filenames=5023]
# [DEBUG] Comparing filename: '28497_ang20231109t071216_006.tif' (filename_num=28497) with label_num=28496 [count_label=2419, count_filenames=5024]
# [DEBUG] Comparing filename: '28497_ang20231109t071216_006.tif' (filename_num=28497) with label_num=28497 [count_label=2420, count_filenames=5024]
# [DEBUG] Comparing filename: '28497_ang20231031t085208_003.tif' (filename_num=28497) with label_num=28497 [count_label=2420, count_filenames=5025]
# [DEBUG] Comparing filename: '28499_ang20231031t085208_002.tif' (filename_num=28499) with label_num=28497 [count_label=2420, count_filenames=5026]
# [DEBUG] Comparing filename: '28499_ang20231031t085208_002.tif' (filename_num=28499) with label_num=28499 [count_label=2421, count_filenames=5026]
# [DEBUG] Comparing filename: '28499_ang20231109t071216_006.tif' (filename_num=28499) with label_num=28499 [count_label=2421, count_filenames=5027]
# Number of files with matching labels: 5025 / 5028
# === Data Aggregation Complete ===

# %% [markdown]
# ### View Data Frames

# %%
df
# Out:
#             frq0      frq1      frq2      frq3      frq4      frq5      frq6  \
# 0       0.029069  0.033152  0.035469  0.041350  0.043226  0.045428  0.048409
# 1       0.030087  0.034019  0.035511  0.041382  0.042764  0.045505  0.049077
# 2       0.037750  0.037187  0.037512  0.041911  0.046044  0.045247  0.046976
# 3       0.037750  0.037187  0.037512  0.041911  0.046044  0.045247  0.046976
# 4       0.031720  0.040508  0.042270  0.042718  0.043992  0.049516  0.051002
# ...          ...       ...       ...       ...       ...       ...       ...
# 448853  0.008262  0.007249  0.010430  0.013172  0.014590  0.016147  0.017221
# 448854  0.002546  0.009940  0.010392  0.014686  0.015467  0.015819  0.018658
# 448855  0.003634  0.012806  0.014233  0.018610  0.017898  0.017720  0.022039
# 448856  0.002516  0.013354  0.012534  0.015690  0.016293  0.016206  0.020137
# 448857  0.002154  0.013795  0.013809  0.018237  0.018999  0.017278  0.022069
#
#             frq7      frq8      frq9  ...    frq368  Sample_num  \
# 0       0.049431  0.052631  0.054922  ...  0.171577           1
# 1       0.049998  0.052073  0.055954  ...  0.193503           1
# 2       0.050844  0.054013  0.057165  ...  0.170450           1
# 3       0.050844  0.054013  0.057165  ...  0.170449           1
# 4       0.052987  0.057484  0.058246  ...  0.180372           1
# ...          ...       ...       ...  ...       ...         ...
# 448853  0.016435  0.020677  0.020636  ...  0.070380       28499
# 448854  0.021157  0.020507  0.019907  ...  0.067679       28499
# 448855  0.023810  0.023159  0.022642  ...  0.102634       28499
# 448856  0.022669  0.020269  0.020936  ...  0.089147       28499
# 448857  0.023353  0.022752  0.022517  ...  0.112213       28499
#
#                         Label     Shape  File_UID_Num  \
# 0       Unconsolidated Barren  (11, 11)             1
# 1       Unconsolidated Barren  (11, 11)             1
# 2       Unconsolidated Barren  (11, 11)             1
# 3       Unconsolidated Barren  (11, 11)             1
# 4       Unconsolidated Barren  (11, 11)             1
# ...                       ...       ...           ...
# 448853    Natural Wooded Land    (8, 8)          4652
# 448854    Natural Wooded Land    (8, 8)          4652
# 448855    Natural Wooded Land    (8, 8)          4652
# 448856    Natural Wooded Land    (8, 8)          4652
# 448857    Natural Wooded Land    (8, 8)          4652
#
#                                     File  img_pxl_index  row_coord  col_coord  \
# 0           1_ang20231028t101421_005.tif              0          0          0
# 1           1_ang20231028t101421_005.tif              1          0          1
# 2           1_ang20231028t101421_005.tif              2          0          2
# 3           1_ang20231028t101421_005.tif              3          0          3
# 4           1_ang20231028t101421_005.tif              4          0          4
# ...                                  ...            ...        ...        ...
# 448853  28499_ang20231109t071216_006.tif             59          7          3
# 448854  28499_ang20231109t071216_006.tif             60          7          4
# 448855  28499_ang20231109t071216_006.tif             61          7          5
# 448856  28499_ang20231109t071216_006.tif             62          7          6
# 448857  28499_ang20231109t071216_006.tif             63          7          7
#
#         img_pos
# 0        (0, 0)
# 1        (0, 1)
# 2        (0, 2)
# 3        (0, 3)
# 4        (0, 4)
# ...         ...
# 448853   (7, 3)
# 448854   (7, 4)
# 448855   (7, 5)
# 448856   (7, 6)
# 448857   (7, 7)
#
# [448858 rows x 378 columns]

# %%
valid_files
# Out:
#                         Label   UID                          Filename
# 0       Unconsolidated Barren     1      1_ang20231028t101421_005.tif
# 1       Unconsolidated Barren     2      2_ang20231028t100428_000.tif
# 2       Unconsolidated Barren     3      2_ang20231028t095542_004.tif
# 3       Unconsolidated Barren     4      3_ang20231028t100428_000.tif
# 4       Unconsolidated Barren     5      3_ang20231028t095542_004.tif
# ...                       ...   ...                               ...
# 4647                 Wetlands  4648  28496_ang20231109t065855_003.tif
# 4648  Mixed or Not Classified  4649  28497_ang20231109t071216_006.tif
# 4649  Mixed or Not Classified  4650  28497_ang20231031t085208_003.tif
# 4650      Natural Wooded Land  4651  28499_ang20231031t085208_002.tif
# 4651      Natural Wooded Land  4652  28499_ang20231109t071216_006.tif
#
# [4652 rows x 3 columns]

# %%
df.drop(['row_coord', 'col_coord'], axis=1, inplace=True)

# %%
df
# Out:
#             frq0      frq1      frq2      frq3      frq4      frq5      frq6  \
# 0       0.029069  0.033152  0.035469  0.041350  0.043226  0.045428  0.048409
# 1       0.030087  0.034019  0.035511  0.041382  0.042764  0.045505  0.049077
# 2       0.037750  0.037187  0.037512  0.041911  0.046044  0.045247  0.046976
# 3       0.037750  0.037187  0.037512  0.041911  0.046044  0.045247  0.046976
# 4       0.031720  0.040508  0.042270  0.042718  0.043992  0.049516  0.051002
# ...          ...       ...       ...       ...       ...       ...       ...
# 448853  0.008262  0.007249  0.010430  0.013172  0.014590  0.016147  0.017221
# 448854  0.002546  0.009940  0.010392  0.014686  0.015467  0.015819  0.018658
# 448855  0.003634  0.012806  0.014233  0.018610  0.017898  0.017720  0.022039
# 448856  0.002516  0.013354  0.012534  0.015690  0.016293  0.016206  0.020137
# 448857  0.002154  0.013795  0.013809  0.018237  0.018999  0.017278  0.022069
#
#             frq7      frq8      frq9  ...    frq366    frq367    frq368  \
# 0       0.049431  0.052631  0.054922  ...  0.156015  0.173310  0.171577
# 1       0.049998  0.052073  0.055954  ...  0.161190  0.170324  0.193503
# 2       0.050844  0.054013  0.057165  ...  0.177692  0.174815  0.170450
# 3       0.050844  0.054013  0.057165  ...  0.177692  0.174815  0.170449
# 4       0.052987  0.057484  0.058246  ...  0.180998  0.189454  0.180372
# ...          ...       ...       ...  ...       ...       ...       ...
# 448853  0.016435  0.020677  0.020636  ...  0.063471  0.067343  0.070380
# 448854  0.021157  0.020507  0.019907  ...  0.062565  0.065229  0.067679
# 448855  0.023810  0.023159  0.022642  ...  0.090310  0.096255  0.102634
# 448856  0.022669  0.020269  0.020936  ...  0.079839  0.085134  0.089147
# 448857  0.023353  0.022752  0.022517  ...  0.091166  0.102596  0.112213
#
#         Sample_num                  Label     Shape  File_UID_Num  \
# 0                1  Unconsolidated Barren  (11, 11)             1
# 1                1  Unconsolidated Barren  (11, 11)             1
# 2                1  Unconsolidated Barren  (11, 11)             1
# 3                1  Unconsolidated Barren  (11, 11)             1
# 4                1  Unconsolidated Barren  (11, 11)             1
# ...            ...                    ...       ...           ...
# 448853       28499    Natural Wooded Land    (8, 8)          4652
# 448854       28499    Natural Wooded Land    (8, 8)          4652
# 448855       28499    Natural Wooded Land    (8, 8)          4652
# 448856       28499    Natural Wooded Land    (8, 8)          4652
# 448857       28499    Natural Wooded Land    (8, 8)          4652
#
#                                     File  img_pxl_index  img_pos
# 0           1_ang20231028t101421_005.tif              0   (0, 0)
# 1           1_ang20231028t101421_005.tif              1   (0, 1)
# 2           1_ang20231028t101421_005.tif              2   (0, 2)
# 3           1_ang20231028t101421_005.tif              3   (0, 3)
# 4           1_ang20231028t101421_005.tif              4   (0, 4)
# ...                                  ...            ...      ...
# 448853  28499_ang20231109t071216_006.tif             59   (7, 3)
# 448854  28499_ang20231109t071216_006.tif             60   (7, 4)
# 448855  28499_ang20231109t071216_006.tif             61   (7, 5)
# 448856  28499_ang20231109t071216_006.tif             62   (7, 6)
# 448857  28499_ang20231109t071216_006.tif             63   (7, 7)
#
# [448858 rows x 376 columns]

# %% [markdown]
# ### Save To CSV

# %%
df.to_csv(path_to_save_sample_csv, index=False)
valid_files.to_csv(path_to_save_uid_csv, index=False)

print(f"Saved pixel-level data to: {path_to_save_sample_csv}")
print(f"Saved file-UID map to:     {path_to_save_uid_csv}")
# Out:
# Saved pixel-level data to: /content/drive/Shareddrives/Land_Classification_Training_shared/Land_Classification_training_work/Updated/samples.csv
# Saved file-UID map to:     /content/drive/Shareddrives/Land_Classification_Training_shared/Land_Classification_training_work/Updated/files.csv
